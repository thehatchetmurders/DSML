# %%
pip install nibabel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\Наргис\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import nibabel as nib

# %%
img = nib.load(r"C:\Users\Наргис\AppData\Local\Programs\Python\Python310\Scripts\data\liver\volume_pt1\volume-0.nii")

# %%
import os
base_path = r"C:/Users/Наргис/AppData/Local/Programs/Python/Python310/Scripts/data/liver"
folder = os.listdir(base_path)
len(folder)
# Out:
# 5

# %%
total_images = 0
for n in range(len(folder)):
    patient_id = folder[n]
    patient_path = base_path + "/" + patient_id 
    class_path = patient_path + "/" 
    subfiles = os.listdir(class_path)
    total_images += len(subfiles)

# %%
total_images
# Out:
# 51

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
img.shape
# Out:
# (512, 512, 75)

# %%
imag = img.get_fdata()
test = imag[:,:,30]
plt.imshow(test)
plt.show()

# %%
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow(imag[:,:,30 + i])
    plt.gcf().set_size_inches(10, 10)
plt.show()

# %%
from scipy.ndimage import gaussian_filter

# %%
data_filtered = gaussian_filter(imag, sigma=1.0)

# %%
plt.imshow(data_filtered[:,:,0])
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.ndimage import zoom

# %%
# data_resized = zoom(imag, zoom=2)
# plt.imshow(data_resized[:,:,0])
# plt.axis('off')
# plt.show

# %%
data_normalized = (imag - imag.min())/(imag.max() - imag.min())
plt.imshow(data_normalized[:,:,0])
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# img_resized = nib.Nifti1Image(data_resized, img.affine)
# nib.save(img_resized, "volume-0(1).nii")

# %%
path_path = r'C:\Users\Наргис\AppData\Local\Programs\Python\Python310\Scripts\data\liver\volume_pt1\volume-0.nii'
# def read_nii(filepath):
#     ct_scan = nib.load(filepath)
#     array   = ct_scan.get_fdata()
# #     array   = np.array(array)
#     array   = np.rot90(np.array(array))
#     return(array)
# read_nii(path_path)

def read_nii(filepath):
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)
# Out:
# array([[[-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         ...,
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.]],
#
#        [[-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         ...,
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.]],
#
#        [[-3024., -3024., -3024., ..., -3024., -3024., -3024.],
#         [-3024., -3024., -3024., ..., -3024., -3024., -3024.],
# ...
